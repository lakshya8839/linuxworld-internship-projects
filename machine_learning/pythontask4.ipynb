# %%
import numpy as np
lst = [1, 2, 3, 4]
arr = np.array(lst)

# %%
print(arr.size)
# Out:
# 4

# %%
print(arr.shape)
# Out:
# (4,)

# %%
print(arr[:3])
# Out:
# [1 2 3]

# %%
print(np.zeros(5))
# Out:
# [0. 0. 0. 0. 0.]

# %%
print(np.ones(5))
# Out:
# [1. 1. 1. 1. 1.]
