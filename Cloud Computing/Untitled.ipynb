# %%
pip install boto3
# Out:
# Requirement already satisfied: boto3 in f:\anaconda\lib\site-packages (1.39.4)
# Requirement already satisfied: botocore<1.40.0,>=1.39.4 in f:\anaconda\lib\site-packages (from boto3) (1.39.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in f:\anaconda\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in f:\anaconda\lib\site-packages (from boto3) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in f:\anaconda\lib\site-packages (from botocore<1.40.0,>=1.39.4->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in f:\anaconda\lib\site-packages (from botocore<1.40.0,>=1.39.4->boto3) (2.2.3)
# Requirement already satisfied: six>=1.5 in f:\anaconda\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.4->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3

# %%
myec2 = boto3.resource("ec2", region_name="ap-southeast-1")

# %%
@app.route("/os")
def oslaunch():
    response = myec2.create_instances(
                InstanceType="t2.micro",
                ImageId="ami-0a3ece531caa5d49d",
                MinCount=1,
                MaxCount=1
    )

    return "os done"

# %%
from flask import Flask

# %%
app = Flask(__name__)

# %%
app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [11/Jul/2025 23:05:00] "GET /os HTTP/1.1" 200 -
